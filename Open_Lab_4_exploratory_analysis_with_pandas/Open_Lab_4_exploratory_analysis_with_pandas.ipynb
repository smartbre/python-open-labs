# %% [markdown]
# # Python Open Labs: Exploratory analysis with pandas
#
# ## Setup
# With this Google Colaboratory (Colab) notebook open, click the "Copy to Drive" button that appears in the menu bar. The notebook will then be attached to your own user account, so you can edit it in any way you like -- you can even take notes directly in the notebook.
#
# ## Instructors
# - Walt Gurley
# - Claire Cahoon
#
# ## Open Labs agenda
#
# 1.   **Guided activity**: One of the instructors will share their screen to work through the guided activity and teach concepts along the way.
#
# 2.   **Open lab time**: After the guided portion of the Open Lab, the rest of the time is for you to ask questions, work collaboratively, or have self-guided practice time. You will have access to instructors and peers for questions and support.
#
# Breakout rooms will be available if you would like to work in small groups. If you have trouble joining a room, ask in the chat to be moved into a room.
#
# ## Learning objectives
#
# By the end of the workshop today, we hope you'll be able to explore datasets using aggregation methods and grouping.
#
# ## Today's Topics
# - Exploratory analysis
# - Unique values
# - Value counts
# - Minimum, maximum, and average
# - Grouping using `groupby()`
#
# ## Questions during the workshop
#
# Please feel free to ask questions throughout the workshop.
#
# We have a second instructor who will available during the workshop. They will answer as able, and will collect questions with answers that might help everyone to be answered at the end of the workshop.
#
# The open lab time is when you will be able to ask more questions and work together on the exercises.
#
# ## Using Jupyter Notebooks and Google Colaboratory
#
# Google Colab notebooks are a way to write and run Python code in an interactive way. If you would like to know more about Colaboratory and how to use notebooks, you can visit the [Welcome Notebook](https://colab.research.google.com/notebooks/welcome.ipynb).
#
# If you'd like to install a Python distribution locally, we're happy to help. Feel free to [get help from our graduate consultants](https://www.lib.ncsu.edu/dxl) or [schedule an appointment with Libraries staff](https://go.ncsu.edu/dvs-request).

# %% [markdown]
# ## Guided Instruction
# In this section, we will work through examples using data from the [Museum of Modern Art (MoMA) research dataset](https://github.com/MuseumofModernArt/collection) containing records of all of the works that have been cataloged in the database of the MoMA collection.
#
# We have prepared a dataset that consists of a subset of MoMA artworks classified as paintings and their associated artist information to use in the following activities. We will be referencing the data that we have prepared in our [Github repository for teaching datasets](https://github.com/ncsu-libraries-data-vis/teaching-datasets/tree/main/moma_data).
#
# ### Exploratory analysis of the dataset
#
# Exploratory analysis is a way to explore or observe our data so that we understand it better and can decide which assessments we want to conduct. After learning how to manipulate and clean data, we can start to analyze it. We can explore questions like:
#
# - How many different artists are represented in the MoMA collection?
# - Which departments have the most works of art?
# - What is the distribution of genders in the MoMA collection? Are some genders better represented in certain departments?
# - What nationalities are represented in the MoMA collection (and how is that data collected)? Have the areas most commonly represented changed over time?
#
# By exploring the data through questions like these, we can find areas of interest for analysis, flaws in the data, or types of data that still need to be collected.
#
# We can do this by calculating summaries of rows and columns, identifying specific values, and grouping data. Next week we will continue with visualizing the results.

# %% [markdown]
# ### Importing the dataset

# %%
# Import the pandas library as pd (callable in our code as pd)
import pandas as pd

# %%
# Import the paintings data from a csv file
# This dataset was cleaned based on methods from previous workshops
paintings_file_url = 'https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_paintings_final.csv'
df = pd.read_csv(paintings_file_url)
# Print out the first five columns of the dataset
df.head()
# Out:
#                         Title         Artist  ConstituentID  \
# 0          Rope and People, I      Joan Miró         4016.0
# 1         Fire in the Evening      Paul Klee         3130.0
# 2  Portrait of an Equilibrist      Paul Klee         3130.0
# 3                      Guitar  Pablo Picasso         4609.0
# 4                 Grandmother    Arthur Dove         1602.0
#
#                         Date  \
# 0  Barcelona, March 27, 1935
# 1                       1929
# 2                       1927
# 3          Paris, early 1919
# 4                       1925
#
#                                               Medium  \
# 0  Oil on cardboard mounted on wood, with coil of...
# 1                                   Oil on cardboard
# 2  Oil and collage on cardboard over wood with pa...
# 3           Oil, charcoal and pinned paper on canvas
# 4  Shingles, needlepoint, page from Concordance, ...
#
#                            Dimensions  \
# 0  41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 1   13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 2     24 7/8 x 15 3/4" (63.2 x 40 cm)
# 3         7' 1" x 31" (216 x 78.8 cm)
# 4       20 x 21 1/4" (50.8 x 54.0 cm)
#
#                                 CreditLine AccessionNumber Classification  \
# 0       Gift of the Pierre Matisse Gallery         71.1936       Painting
# 1  Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 2               Mrs. Simon Guggenheim Fund        195.1966       Painting
# 3               Gift of A. Conger Goodyear        384.1955       Painting
# 4  Gift of Philip L. Goodwin (by exchange)        636.1939       Painting
#
#              Department  ...                            ArtistBio Nationality  \
# 0  Painting & Sculpture  ...                   Spanish, 1893–1983     Spanish
# 1  Painting & Sculpture  ...  German, born Switzerland. 1879–1940      German
# 2  Painting & Sculpture  ...  German, born Switzerland. 1879–1940      German
# 3  Painting & Sculpture  ...                   Spanish, 1881–1973     Spanish
# 4  Painting & Sculpture  ...                  American, 1880–1946    American
#
#    Gender  BeginDate  EndDate  Area (cm^2)    Aspect  OilPainting  \
# 0    male     1893.0   1983.0      7818.08  0.711832            Y
# 1    male     1879.0   1940.0      1125.54  0.985207            Y
# 2    male     1879.0   1940.0      2219.04  0.610282            Y
# 3    male     1881.0   1973.0     16991.33  0.364521            Y
# 4    male     1880.0   1946.0      2743.20  1.062992            N
#
#    YearCreated  AspectString
# 0       1935.0      Portrait
# 1       1929.0      Portrait
# 2       1927.0      Portrait
# 3       1919.0      Portrait
# 4       1925.0     Landscape
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Aggregation Methods
#
# There are several methods that can be used to calculate aggregated values from the dataset, such as the number of unique values, unique value counts, minimum, maximum, and average.

# %% [markdown]
# #### Unique
# `unique()` will return an array containing each unique value in a column of data. That means that duplicate values are only shown once, so it is a useful tool for finding each different reponse in a column of data. If we were interested in how many different responses there were, we could use the `len()` function to find the length of that array.
#
# In this example, we use the `unique()` method on the "Artist" column to create an array of unique artist names to see each artist that is represented in the collection. The length of this array will provide the number of unique artist.

# %%
# Create a list of the unique artists with unique()
unique_artist = list(df['Artist'].unique())
# Print out the unique artists
unique_artist
# Out:
# ['Joan Miró',
#  'Paul Klee',
#  'Pablo Picasso',
#  'Arthur Dove',
#  'Francis Picabia',
#  'Blinky Palermo',
#  'Pierre Roy',
#  'Paul Cézanne',
#  'Enrico Prampolini',
#  'Jankel Adler',
#  'Robert Delaunay',
#  'Jean Bazaine',
#  'Elmer Bischoff',
#  'Vasudeo S. Gaitonde',
#  'Barnett Newman',
#  'Preston Dickinson',
#  'Piet Mondrian',
#  'James Edward Davis',
#  'Georges Braque',
#  'Francisco Borès',
#  'Wilson Bigaud',
#  'Franz Kline',
#  'Vasily Kandinsky',
#  'Hans Hofmann',
#  'Paul Gauguin',
#  'John Randall Bratby',
#  'Jean McEwen',
#  'James Francis Gill',
#  'Michael Gross',
#  'Check  Boterf',
#  'Glenn Ligon',
#  'Edward Hopper',
#  'Otto Dix',
#  'Niles Spencer',
#  'Frida Kahlo',
#  'Alfonso Ossorio',
#  'Charles Hinman',
#  'Eduardo A. MacEntyre',
#  'James Rosenquist',
#  'David Alfaro Siqueiros',
#  'Emilio Pettoruti',
#  'Loren MacIver',
#  'Nassos Daphnis',
#  'Antonio Corpora',
#  'Mark Tobey',
#  'Leonardo Cremonini',
#  'Sam Francis',
#  'Agnes Martin',
#  'Kenneth Noland',
#  'Cy Twombly',
#  'Piero Manzoni',
#  'Thomas Hart Benton',
#  'John Kane',
#  'Max Beckmann',
#  'Antonio Ruiz',
#  'Julio Castellanos',
#  'Balcomb Greene',
#  'André Derain',
#  'Adolph Gottlieb',
#  'Burgoyne Diller',
#  'Grace Hartigan',
#  'Jackson Pollock',
#  'Larry Zox',
#  'Hyman Bloom',
#  'Henri Matisse',
#  'Lee Gatch',
#  'Giacomo Balla',
#  'Philip Guston',
#  'Richard Lindner',
#  'Ibrahim El-Salahi',
#  'Florine Stettheimer',
#  'Jasper Johns',
#  'James Jarvaise',
#  'Carl-Henning Pedersen',
#  'Tadasky (Tadasuke Kuwayama)',
#  'Stuart Davis',
#  'Ida E. Fischer',
#  'Willi Baumeister',
#  'Robert Goodnough',
#  'Ellsworth Kelly',
#  'Max Schnitzler',
#  'Fletcher Martin',
#  'Alberto da Veiga Guignard',
#  'Theora Hamblett',
#  'Gustav Klimt',
#  'Raphael Soyer',
#  'Fernand Léger',
#  'Max Ernst',
#  'Rafael Moreno',
#  'Herman Rose',
#  'Ernst Ludwig Kirchner',
#  'Lucian Freud',
#  'James McGarrell',
#  'Amedeo Modigliani',
#  'Antoni Tàpies',
#  'Francis Alÿs',
#  'Walt Kuhn',
#  'Oskar Kokoschka',
#  'Armando Morales Sequeira',
#  'Liubov Popova',
#  'Ger Lataster',
#  'Elizabeth Peyton',
#  'Alberto Giacometti',
#  'Robert Motherwell',
#  'Victor Vasarely',
#  'Andrew Wyeth',
#  'René Magritte',
#  'Roberto Matta',
#  'August Macke',
#  'Jan Müller',
#  'Honoré Sharrer',
#  'Roberto Ossaye',
#  'George McNeil',
#  'Max Weber',
#  'László Moholy-Nagy',
#  'Abraham Rattner',
#  'John Tunnard',
#  'John Piper',
#  'Emil Nolde',
#  'Otto Mueller',
#  'Jeanne Reynal',
#  'Morgan Russell',
#  'Mark Rothko',
#  'Stanley Spencer',
#  'Zoran Mušič',
#  'Iaroslav Serpan',
#  'Will Barnet',
#  'Diego Rivera',
#  'Pierre Soulages',
#  'Christian Bérard',
#  'Ilya Bolotowsky',
#  'Larry Rivers',
#  'Myron Stout',
#  'Jean-Paul Riopelle',
#  'Giuseppe Guerreschi',
#  'Kumi Sugaï',
#  'Modest Cuixart',
#  'Susan Rothenberg',
#  'Oliver Jackson',
#  'Richard Oelze',
#  'Theodoros Stamos',
#  'Donald Sultan',
#  'Alice Neel',
#  'Neil Jenney',
#  'Jacob Lawrence',
#  'Nicolas de Staël',
#  'Peter Blume',
#  'Maria Helena Vieira da Silva',
#  'Wols (A. O. Wolfgang Schulze)',
#  'Arthur B. Davies',
#  'Mariano (Mariano Rodríguez)',
#  'Raoul Ubac',
#  'Jack Tworkov',
#  'Raymond Parker',
#  'Alex Katz',
#  'Clara McDonald Williamson',
#  'William Ronald',
#  'Man Ray (Emmanuel Radnitzky)',
#  'Meret Oppenheim',
#  'Antoine Pevsner',
#  'Sarai Sherman',
#  'Benny Andrews',
#  'Mikhail Larionov',
#  'Dorothea Rockburne',
#  'Mordecai Ardon',
#  'Séraphine Louis',
#  'Alan Shields',
#  'Paul Burlin',
#  'Bruce Boice',
#  "Allan D'Arcangelo",
#  'Hedda Sterne',
#  'Toni Costa',
#  'Richard Tuttle',
#  'Wojciech Fangor',
#  'Richard Smith',
#  'Marcos Grigorian',
#  'George Grosz',
#  'Hans Hartung',
#  'Lothar Quinte',
#  'Fritz Glarner',
#  'Mohsen Vaziri Moghaddam',
#  'Israel Litwak',
#  'André Marchand',
#  'William Bailey',
#  'Bradley Walker Tomlin',
#  'Red Grooms',
#  'René Robert Bouché',
#  'Raoul Dufy',
#  'On Kawara',
#  'Jorge Damiani',
#  'Jean Dubuffet',
#  'Umberto Boccioni',
#  'Richard Artschwager',
#  'Milton Avery',
#  "Georgia O'Keeffe",
#  'Guy Pène du Bois',
#  'Marsden Hartley',
#  'Virginia Admiral',
#  'Leon Polk Smith',
#  'Georg Baselitz',
#  'Balthus (Baltusz Klossowski de Rola)',
#  'Pierre Bonnard',
#  'Jimmy Ernst',
#  'Cundo Bermúdez',
#  'Robert Colescott',
#  'Vern Blosum',
#  'Eva Hesse',
#  'Enrico Donati',
#  'Lester F. Johnson',
#  'Jean (Hans) Arp',
#  'Robert Hansen',
#  'Joan Snyder',
#  'Guido Molinari',
#  'Jean Hélion',
#  'Ida Applebroog',
#  'Willem de Kooning',
#  'Maurice Sievan',
#  'Yves Tanguy',
#  'Roger van Rogger',
#  'David Simpson',
#  'Morris Louis',
#  'Rufino Tamayo',
#  'Elsa Schmid',
#  'Georges Rouault',
#  'Tom Wesselmann',
#  'Robert Rauschenberg',
#  'Amelia Peláez Del Casal',
#  'Maurice de Vlaminck',
#  'Joan Brown',
#  'Harry Zolotow',
#  'Helen Frankenthaler',
#  'Ad Reinhardt',
#  'Juan Gris',
#  'Natalia Goncharova',
#  'André Masson',
#  'Sean Scully',
#  'Bernard Buffet',
#  'Renato Guttuso',
#  'Knud Merrild',
#  'Paul Signac',
#  'Giorgio de Chirico',
#  'Andy Warhol',
#  'Arshile Gorky',
#  'Joseph Mellor Hanson',
#  'Miguel Ocampo',
#  'Kurt Seligmann',
#  'Chaim Soutine',
#  'Roy Adzak',
#  'Albert Tucker',
#  'Gene Davis',
#  'Genichiro Inokuma',
#  'Jake Berthot',
#  'Forrest Bess',
#  'Edwin Dickinson',
#  'Louis Cane',
#  'Albert Bloch',
#  'Richard Bosman',
#  'Richard Pousette-Dart',
#  'Joan Josep Tharrats',
#  'Eugene Fernandez Granell',
#  'Édouard Vuillard',
#  'Ralph Goings',
#  'Rico Lebrun',
#  'Simon Hantaï',
#  'Agam (Yaacov Agam)',
#  'Leonard French',
#  'Al Held',
#  'Peter Young',
#  'Donald Judd',
#  'Ben Cunningham (Benjamin Frazier Cunningham)',
#  'Piero Dorazio',
#  'Ronald Markman',
#  'Chuck Close',
#  'William Gropper',
#  'Eugenie Baizerman',
#  'Jorge Eielson',
#  'Mark Lancaster',
#  'Robert Kushner',
#  'Pamela Bianco',
#  'R. B. Kitaj',
#  'Sigmar Polke',
#  'Otto Freundlich',
#  'Seiji Chokai',
#  'Jane Wilson',
#  'Gandy Brodie',
#  'Karel Appel',
#  'Elizabeth Murray',
#  'Rudolf Baranik',
#  'Zbigniew Makowski',
#  'Francis Celentano',
#  'Gastone Novelli',
#  'Ger van Elk',
#  'Aleksandr Rodchenko',
#  'Romare Bearden',
#  'Horia Damian',
#  'Émile Bernard',
#  'Oli Sihvonen',
#  'Arnold Schmidt',
#  'Jules Olitski',
#  'Audrey Flack',
#  'Roland Dorcély',
#  'Walter Zehringer',
#  'Robyn Denny',
#  'Alfred Jensen',
#  'Leon Golub',
#  'Nicholas Krushenick',
#  'Agustín Fernández',
#  'Ahmed Yacoubi',
#  'Franz Marc',
#  'Arnold Friedman',
#  'Zvi Gali',
#  'James Henry Daugherty',
#  'Peter Saul',
#  'Philip Evergood',
#  'Richard Hamilton',
#  'Jim Nutt',
#  'Sam Joseph Ntiro',
#  'Octave Landuyt',
#  'Wayne Thiebaud',
#  'Evert Lundquist',
#  'Gwen John',
#  'Frans Krajcberg',
#  'Georges-Pierre Seurat',
#  'Gregory Amenoff',
#  'Malcolm Morley',
#  'Frank Bowling',
#  'Bruno Ceccobelli',
#  'Graham Sutherland',
#  'Richard Lytle',
#  'Erol (Erol Akyavas)',
#  'George Ault',
#  'Gary Stephan',
#  'Jack Levine',
#  'Thomas Wilfred',
#  'Robert Mangold',
#  'A. E. Gallatin',
#  'Manolo Millares',
#  'Robert Ryman',
#  'Theo van Doesburg',
#  'John Atherton',
#  'Claude Viallat',
#  'Charles Seliger',
#  'David Hockney',
#  'Jewett Campbell',
#  'Karl Knaths',
#  'Irving Kriesberg',
#  'Patrick Scott',
#  'František Kupka',
#  'Ben Shahn',
#  'Horace Pippin',
#  'Joseph Stella',
#  'Charles Sheeler',
#  'Marc Chagall',
#  'Heinrich Campendonk',
#  'John Covert',
#  'Marcel Duchamp',
#  'Giuseppe Capogrossi',
#  'René Vincent',
#  'Brice Marden',
#  'John Baldessari',
#  'David Deutsch',
#  'Yvonne Jacquette',
#  'Karl Schmidt-Rottluff',
#  'Sidney Goodman',
#  'Ernest  Trova',
#  'Fritz Winter',
#  'Salvador Dalí',
#  'Sophie Calle',
#  'Walter Quirt',
#  'Amédée Ozenfant',
#  'Roy Lichtenstein',
#  'Maurice Prendergast',
#  'Gerhard Richter',
#  'Attilio Salemme',
#  'El Lissitzky',
#  'Oscar Domínguez',
#  'Jose Antonio Fernández-Muro',
#  'Elmer Schooley',
#  'Felix Gonzalez-Torres',
#  'Anselm Kiefer',
#  'Armando Pizzinato',
#  'Alan Reynolds',
#  'Alan Davie',
#  'Richard Diebenkorn',
#  'Georges Ribemont-Dessaignes',
#  'William Baziotes',
#  'Eric Fischl',
#  'Sonia Delaunay-Terk',
#  'Robert Natkin',
#  'Kees van Dongen',
#  'John Levee',
#  'Janet Sobel',
#  'Robin Winters',
#  'Vincent van Gogh',
#  'Gérard Schneider',
#  'Alfred Manessier',
#  'Georges Mathieu',
#  'Enrique Zañartu',
#  'Thomas Chimes',
#  'Jonathan Borofsky',
#  'Fairfield Porter',
#  'Emilio Rodríguez Larraín',
#  'José Clemente Orozco',
#  'Gino De Dominicis',
#  'Joseph Glasco',
#  'Ronald Bladen',
#  'Ralph Humphrey',
#  'Jacques Villon',
#  'Joe Goode',
#  'Eugene Berman',
#  'Nedo Mion Ferrario',
#  'Katherine Porter',
#  'Onofrio A. Pacenza',
#  'Lee Krasner',
#  'Frank Stella',
#  'Mark Tansey',
#  'Odilon Redon',
#  'Jean Charlot',
#  'Roger de La Fresnaye',
#  'Marcel Broodthaers',
#  'Ivan LeLorraine Albright',
#  'René Brô',
#  'Francis Bacon',
#  'Sally Hazelet Drummond',
#  'Patrick Henry Bruce',
#  'Daniel Buren',
#  'Arnulf Rainer',
#  'Edward Ruscha',
#  'Pierre Clerk',
#  'Bedri Rahmi',
#  'Carlo Carrà',
#  'Robert Irwin',
#  'Christopher Wool',
#  'Robert Colquhoun',
#  'Robert Kabak',
#  'Enzo Cucchi',
#  'Claude Monet',
#  'Ron Davis',
#  'Jo Baer',
#  'James Brooks',
#  'Kazimir Malevich',
#  'Kenzo Okada',
#  'Frederick Papsdorf',
#  'Afro (Afro Basaldella)',
#  'Reuven Rubin',
#  'Henri Rousseau',
#  'Robert MacBryde',
#  'Pavel Tchelitchew',
#  'Edmondo Bacci',
#  'Howard Mehring',
#  'Edward Corbett',
#  'Luis Fernando Benedit',
#  'Ree Morton',
#  'Marina Stern',
#  'Sandra Blow',
#  'Lyonel Feininger',
#  'Stefan Knapp',
#  'Kirsten Kraa',
#  'Le Corbusier (Charles-Édouard Jeanneret)',
#  'Erich Buchholz',
#  'Norman Bluhm',
#  'Julian E. Levi',
#  'Reginald Marsh',
#  'Paul-Émile Borduas',
#  'Thomas Sills',
#  'Barbara Kruger',
#  'Herbert Bayer',
#  'Philomé Obin',
#  'Robert Longo',
#  "Roderic O'Conor",
#  'Larry Poons',
#  'Michelle Stuart',
#  'Jan Lebenstein',
#  'Terry Winters',
#  'Llyn Foulkes',
#  'René Pierre Tal-Coat',
#  'Josef Albers',
#  'Maurice Sterne',
#  'Shirley Jaffe',
#  'Clyfford Still',
#  'Ross Bleckner',
#  'Katherine S. Dreier',
#  'Fernando Botero',
#  'Rackstraw Downes',
#  'Salvatore Fiume',
#  'Joaquín Torres-García',
#  'Emilio Vedova',
#  'Theodor Werner',
#  'Christo',
#  'Karl Hofer',
#  'Carlos Cruz-Diez',
#  'Markus Lüpertz',
#  'Karin Sander',
#  'Stephen Greene',
#  'David Salle',
#  'Giorgio Morandi',
#  'Marcello Muccini',
#  'Robert Indiana',
#  'George Sugarman',
#  'Gino Severini',
#  'Reuben Tam',
#  'Philippe Hosiasson',
#  'Jóhannes Sveinsson Kjarval',
#  'Nagwaraba',
#  'Alfred H. Maurer',
#  'Mel Bochner',
#  'Michelangelo Pistoletto',
#  'Yasuo Kuniyoshi',
#  'Antonio Segui',
#  'Maurice Utrillo',
#  'John Walker',
#  'Joan Witek',
#  'Martin Kippenberger',
#  'Robert Moskowitz',
#  'André Bauchant',
#  'Ronnie Landfield',
#  'Fannie Hillsmith',
#  'Joseph Ndandarika',
#  'William Congdon',
#  'Mohan B. Samant',
#  'José María Sicilia',
#  'Conrad Marca-Relli',
#  'Tony Smith',
#  'Jean Lurçat',
#  'Arthur Osver',
#  'Sidney Nolan',
#  'J. Trevor Wood',
#  'Irene Rice Pereira',
#  'Stanislao Lepri',
#  'Kay Sage',
#  'Walter Richard Sickert',
#  'Stanton Macdonald-Wright',
#  'Jim Dine',
#  'Ellen Gallagher',
#  'Richard Anuszkiewicz',
#  'Mowry Thatcher Baden',
#  'Lois Lane',
#  'David Novros',
#  'Sue Williams',
#  'Bernard Cohen',
#  'André Lanskoy',
#  'Joan Mitchell',
#  'Patrick J. Sullivan',
#  'George Tooker',
#  'Alex Colville',
#  'Miroslav Sutej',
#  'Ulysse Comtois',
#  'Philip Taaffe',
#  'Graham Coughtry',
#  'William Kurelek',
#  'Bob Thompson',
#  'Lynton Wells',
#  'Alexander Liberman',
#  'Carroll Dunham',
#  'Saliba Douaihy',
#  'Richard Pettibone',
#  'Kazuo Nakamura',
#  'Malcolm Bailey',
#  'John Opper',
#  'Günther Förg',
#  'Mark Innerst',
#  'Evsa Model',
#  'Mimmo Paladino',
#  'Nina Tryggvadottir',
#  'Arthur B. Carles',
#  'Milton Resnick',
#  'Louis Michel Eilshemius',
#  'Julius Bissier',
#  'Jean Metzinger',
#  'Lucio Fontana',
#  'Alexei Jawlensky',
#  'Paul van Hoeydonck',
#  'David Smith',
#  'Alice Baber',
#  'Robert Barry',
#  'Allan McCollum',
#  'Sandro Chia',
#  'Otto Piene',
#  'Auguste Herbin',
#  'Howard Hodgkin',
#  'Robert Huot',
#  'Mario Merz',
#  'Jess',
#  'A.R. Penck (Ralf Winkler)',
#  'Brad Davis',
#  'Hisao Domoto',
#  'Thomas Nozkowski',
#  'Varvara Stepanova',
#  'Matthew Abbott',
#  'Antonio López García',
#  'César Paternosto',
#  'Egon Schiele',
#  'Annette Messager',
#  'Theodore Lux Feininger',
#  'David Wojnarowicz',
#  'Roberto Berdecio',
#  'Moses Soyer',
#  'Lovis Corinth',
#  'Jack Youngerman',
#  'Morris Hirshfield',
#  'Louis Marcoussis',
#  'Thomas Mukarobgwa',
#  'Philip Pearlstein',
#  'Satish Gujral',
#  'Elizabeth Sparhawk-Jones',
#  'Martin Baer',
#  'Hermann Nitsch',
#  'Luc Tuymans',
#  'Mario Sironi',
#  'Karl Zerbe',
#  'Kurt Roesch',
#  'Abraham Walkowitz',
#  'Giorgio Cavallon',
#  'Olle Baertling',
#  'John Ferren',
#  'Jedd Garet',
#  'Frederick Kiesler',
#  'Lynn Bowers',
#  'Carroll Cloar',
#  'Max Oppenheimer (MOPP)',
#  'Paul Delvaux',
#  'James Ensor',
#  'Henri Le Fauconnier',
#  'Eleanore Mikus',
#  'Esteban Vicente',
#  'Harold Barling Town',
#  'Paul Feeley',
#  'Pat Steir',
#  'Ivo Pannaggi',
#  'Alton Pickens',
#  'Louis Vivin',
#  'Roger Bissière',
#  'Robert Morris',
#  'Michael Venezia',
#  'Jack Whitten',
#  'Annette Lemieux',
#  'Per Kirkeby',
#  'Grégoire Müller',
#  'Norman Lewis',
#  'Jean Fautrier',
#  'David Prentice',
#  'Joseph Pickett',
#  'Alberto Burri',
#  'Wallace Putnam',
#  'Roberto Montenegro',
#  'Jules Pascin',
#  'David Burliuk',
#  'Peter Purves-Smith',
#  'John Day',
#  'Joseph Hirsch',
#  'Lawrence Stephen Lowry',
#  'Mitchell Siporin',
#  'Everett Spruce',
#  'Byron Thomas',
#  'Maurice Grosser',
#  'Bridget Riley',
#  'Leonid (Leonid Berman)',
#  'Serge Poliakoff',
#  'Eugène Carrière',
#  'Suzanne Valadon',
#  'Victor Brauner',
#  'Gianfranco Baruchello',
#  'William Doriani',
#  'Tom Blackwell',
#  'Santiago Cárdenas',
#  'John Clem Clarke',
#  'Maud Morgan',
#  'Juan Genovés',
#  'Richard Estes',
#  'Ron Kleemann',
#  'Oskar Schlemmer',
#  'Öyvind Fahlström',
#  'Takeshi Kawashima',
#  'Fidelio Ponce De León',
#  'Jörg Immendorff',
#  'Nathan Oliveira',
#  'Shuji Mukai',
#  'Miguel Angel Ríos',
#  'Atsuko Tanaka',
#  'Takeo Yamaguchi',
#  'Salvatore Scarpitta',
#  'Mervin Jules',
#  'Bryan Wynter',
#  'Manoucher Yektai',
#  'Yves Klein',
#  'Raúl Anguiano',
#  'John D. Graham',
#  'Billy Al Bengston',
#  'Lawrence Lebduska',
#  'Bruce Tippett',
#  'Gonzalo Ariza',
#  'Henri Laurens',
#  'Anton Refregier',
#  'Nicholas Africano',
#  'Edward C. ("Pa") Hunt',
#  'Antonio Berni',
#  'Francesco Clemente',
#  'Yayoi Kusama',
#  'Ben Nicholson',
#  'Fred Tomaselli',
#  'Marcelo Bonevardi',
#  'Albert Urban',
#  'Camille Bombois',
#  'Candido Portinari',
#  'Dominique-Paul Peyronnet',
#  'Tom Holland',
#  'Renato Cristiano',
#  'Luis Martínez Pedro',
#  'Hundertwasser (Friedrich Stowasser)',
#  'Christopher Le Brun',
#  'Raquel Forner',
#  'Douglas Blau',
#  'Cleve Gray',
#  'Alfredo Guido',
#  'Guillermo Kuitca',
#  'Wally Hedrick',
#  'Alfred Leslie',
#  'Peter Dechar',
#  'Matthew Rackham Barnes',
#  "Juan O'Gorman",
#  'Walter Stuempfig',
#  'José Pancetti',
#  'Lorser Feitelson',
#  'William Copley',
#  'Heitor dos Prazeres',
#  'William Pettet',
#  'Mario Urteaga',
#  'Alfredo Zalce',
#  'Jennifer Bartlett',
#  'Sue Coe',
#  'Walter Darby Bannard',
#  'Roger Brown',
#  'Dan Christensen',
#  'Alan Cote',
#  'Iurii Annenkov',
#  'Hap Tivey',
#  'Neil Welliver',
#  'Sándor (Alexander) Bortnyik',
#  'Carl Buchheister',
#  'Ad Dekkers',
#  'Walter Dexel',
#  'Rollin Crampton',
#  "Lajos D'Ebneth",
#  'Alexandra Exter',
#  'Henry Pearson',
#  'Adolf Richard Fleischmann',
#  'Moshe Elazar Castel',
#  'Sophie Taeuber-Arp',
#  'William T. Williams',
#  'Camille Graeser',
#  'Gotthard Graubner',
#  'Gertrude Greene',
#  'Vilmos Huszár',
#  'Will Insley',
#  'Johannes Itten',
#  'Ivan Kliun',
#  'Bart van der Leck',
#  'Richard Paul Lohse',
#  'Paul (Pavel Mansurov) Mansouroff',
#  'Mikhail Matiushin',
#  'John McLaughlin',
#  'George L. K. Morris',
#  'Marlow Moss',
#  'Victor Pasmore',
#  'Edda Renouf',
#  'Olga Rozanova',
#  'Ludwig Sander',
#  'Jan J. Schoonhoven',
#  'Kurt Schwitters',
#  'Victor Servranckx',
#  'Wladyslaw Strzemiński',
#  'Georges Vantongerloo',
#  'Bernar Venet',
#  'Friedrich Vordemberge-Gildewart',
#  'Charmion von Wiegand',
#  'Marcel Jean',
#  'Gerald Murphy',
#  'Wolfgang Paalen',
#  'Billy Sullivan',
#  'Sam Gilliam',
#  'Ron Gorchov',
#  'Joanna Pousette-Dart',
#  'Augustus Vincent Tack',
#  'Alighiero Boetti',
#  'Chris Ofili',
#  'Ed Moses',
#  'Edvard Munch',
#  'James Bishop',
#  'Donald  Kaufman',
#  'Paul Jenkins',
#  'Dimitri Mikhailovich Krasnopevtsev',
#  'Vladimir Nikolaevich Nemukhin',
#  'Dimitri Petrovich Plavinsky',
#  'Alexei Alexandrovich Tyapushkin',
#  'Shusaku Arakawa',
#  'Zbigniew Gostomski',
#  'Key Hiraga',
#  'Bhupen P. Khakhar',
#  'Augusto Giacometti',
#  'Daniel LaRue Johnson',
#  'Alejandro Otero',
#  'Shirazeh Houshiary',
#  'Christina Ramberg',
#  'Vija Celmins',
#  'Bruce Nauman',
#  'Beatriz Milhazes',
#  'Ellen Phelan',
#  'Chéri Samba',
#  'Takashi Murakami',
#  'Lee Lozano',
#  'Sherrie Levine',
#  'Peter Doig',
#  'Hélio Oiticica',
#  'Armando Reverón',
#  'Julie Mehretu',
#  'John Currin',
#  'Lisa Yuskavage',
#  'Suzanne Duchamp',
#  'Thomas Scheibitz',
#  'Arman',
#  'Max Bill',
#  'Albert Gleizes',
#  'Eberhard Havekost',
#  'Sarah Morris',
#  'Stefan Kürten',
#  'Julian Stanczak',
#  'Magnus Plessen',
#  'Wilhelm Sasnal',
#  'Dana Schutz',
#  'Richard Wright',
#  'Bob Kane',
#  'Harvey Quaytman',
#  'David Webster',
#  'Raqib Shaw',
#  'Carmen Herrera',
#  'Tim Bavington',
#  'Marlene Dumas',
#  'Mangelos (Dimitrije Bašičević)',
#  'Gabriel Orozco',
#  'Mira Schendel',
#  'Al Hansen',
#  'François Morellet',
#  'Albert York',
#  'Willys de Castro',
#  'Wade Guyton',
#  'Reena Spaulings',
#  'Amy Sillman',
#  'Lucy McKenzie',
#  'Alejandro Puente',
#  'Abraham Palatnik',
#  'Frank Auerbach',
#  'Rosemarie Trockel',
#  'Lygia Clark',
#  'Sandra Gamarra',
#  'Batiste Madalena',
#  'Sergej Jensen',
#  'Blake Rayne',
#  'Judit Reigl',
#  'Kai Althoff',
#  'Beatriz González',
#  'Kelley Walker',
#  'Ben Vautier',
#  'George Maciunas',
#  'R. H. Quaytman',
#  'Eduardo Costa',
#  'Josh Smith',
#  'Jacqueline Humphries',
#  'Alfredo Volpi',
#  'Yoko Ono',
#  'Nam June Paik',
#  'Ay-O',
#  'Dorothea Tanning',
#  'Lee Bontecou',
#  'George Condo',
#  'Lee Ufan',
#  nan,
#  'Lawrence Weiner',
#  'Joseph Kosuth',
#  'Jutta Koether',
#  'Charline von Heyl',
#  'Peter Halley',
#  'Adam Pendleton',
#  'Kerstin Brätsch',
#  'Mark Grotjahn',
#  'Lidy Prati',
#  'Jacques Charlier',
#  'Alain Jacquet',
#  'Peter Klasen',
#  'Niele Toroni',
#  'Cheyney Thompson',
#  'Martin Wong',
#  'Joe Bradley',
#  'Albert Oehlen',
#  'Mona Hatoum',
#  'Beauford Delaney',
#  'Tomma Abts',
#  'Saburo Murakami',
#  'Henry Taylor',
#  'Sylvia Plimack Mangold',
#  'Arch Connelly',
#  'Michael Krebber',
#  'Isa Genzken',
#  'Tauba Auerbach',
#  'Michel Parmentier',
#  'Allen Ruppersberg',
#  'Mary Weatherford',
#  'Betye Saar',
#  'Geta Brătescu',
#  'Matt Connors',
#  'Paulo Monteiro',
#  'Julije Knifer',
#  'Al Loving',
#  'Jan Dibbets',
#  'Laura Owens',
#  'Ryan Sullivan',
#  'Jeff Elrod',
#  'Robert Gober',
#  'Michael Williams',
#  'Nicole Eisenman',
#  'Ed Clark',
#  'Michel Majerus',
#  'Maria Lassnig',
#  'Mladen Stilinović',
#  'Howardena Pindell',
#  'Lari Pittman',
#  'Denise Green',
#  'Carlos Zilio',
#  'Alex Israel',
#  'Lynette Yiadom-Boakye',
#  'Hale Woodruff',
#  'Jack Goldstein',
#  'Julian Schnabel',
#  'Kerry James Marshall',
#  'Sarah Grilo',
#  'Alma Woodsey Thomas',
#  'Ha Chong-Hyun',
#  'Etel Adnan',
#  'Richard Aldrich',
#  'Park Seo Bo',
#  'Mary Heilmann',
#  'Michaela Eichwald',
#  'Kim Beom',
#  'Mark Bradford',
#  'Faith Ringgold',
#  'William H. Johnson',
#  'Tarsila do Amaral',
#  'Mark di Suvero',
#  'Avery Singer',
#  'Konrad Lueg',
#  'Hércules Barsotti',
#  'Omar Carreño',
#  'Aluisio Carvão',
#  'Waldemar Cordeiro',
#  'Geraldo de Barros',
#  'Hermelindo Fiaminghi',
#  'María Freire',
#  'Carlos González Bogen',
#  'Elsa Gramcko',
#  'Alfredo Hlito',
#  'Judith Lauand',
#  'Gerd Leufert',
#  'Raúl Lozza',
#  'Tomás Maldonado',
#  'Mateo Manaure',
#  'Juan Melé',
#  'Juan Alberto Molenberg',
#  'Rubén Núñez',
#  'Lygia Pape',
#  'Rhod Rothfuss',
#  'Luiz Sacilotto',
#  'Ivan Serpa',
#  'Antonieta Sosa',
#  'Jesús Rafael Soto',
#  'Rubem Valentim',
#  'Gregorio Vardanega',
#  'Virgilio Villalba',
#  'Kazuo Shiraga',
#  'Zilia Sánchez',
#  'Paula Modersohn-Becker',
#  'Jenny Holzer',
#  'Yinka Shonibare',
#  'Richard Prince',
#  'Chung Chang-Sup',
#  'Carmelo Arden Quin',
#  'Barkley L. Hendricks',
#  'Sylvia Sleigh',
#  'Rosalyn Drexler',
#  'Eugenio Espinoza',
#  'José Leonilson',
#  'Roberto Obregón',
#  'Silke Otto-Knapp',
#  'David Reed',
#  'Joan Semmel',
#  'Sonja Sekula',
#  'Lois Dodd',
#  'Hervé Télémaque',
#  'Cecily Brown',
#  'General Idea',
#  'Ulrike Müller',
#  'Cecilia Vicuña',
#  ...]

# %%
# Get the length of the new array using len()
# How many unique species are there?
len(unique_artist)
# Out:
# 1018

# %% [markdown]
# #### Value counts
#
# `.value_counts()` show how many instances there are of each unique entry in a column. It lists each unique value and how many times it appears in a column of data.
#
# Here, we are interested in seeing the nationalities of artists in order to figure out which areas of the world are most represented in MoMA.
#
# We will specify the `Nationality` column in our Dataframe and call the method `value_counts()`. This will return a Series with an index label of each nationality from the data and a value corresponding to the count of how many times that nationality is lsited in the 'Nationality' column of the DataFrame.

# %%
# Count the occurance of unique values on the column 'Nationality'
df['Nationality'].value_counts()

# Sort the Series by the value counts using sort_values()
df['Nationality'].value_counts().sort_values(ascending=False)
# Out:
# American         1149
# French            321
# German            129
# Spanish            96
# British            87
# Italian            75
# Japanese           55
# Brazilian          48
# Venezuelan         35
# Dutch              35
# Belgian            35
# Russian            32
# Argentine          31
# Mexican            28
# Swiss              20
# Austrian           19
# Canadian           14
# Cuban              12
# Uruguayan          12
# Israeli             8
# Polish              8
# Chilean             8
# Australian          8
# Danish              6
# Romanian            6
# Congolese           5
# Indian              5
# Korean              5
# Colombian           5
# Czech               5
# Haitian             5
# Peruvian            4
# Hungarian           4
# Swedish             3
# South African       3
# Croatian            3
# Icelandic           2
# Zimbabwean          2
# Yugoslav            2
# Irish               2
# Turkish             2
# Iranian             2
# Norwegian           1
# Ukrainian           1
# Slovenian           1
# Bolivian            1
# Guyanese            1
# Tanzanian           1
# Moroccan            1
# Guatemalan          1
# Nicaraguan          1
# Sudanese            1
# Lebanese            1
# Name: Nationality, dtype: int64

# %% [markdown]
# `.value_counts()` can also be a useful exploratory tool. You are able to see how many different categories are in a particular column and if there are areas that you would like to investigate more.
#
# For example, our data today only contains artwork that is classified as a "painting" in the `Classification` column. However, if we look at the `.value_counts()` to show how many pieces of art are in each department, we can see that they aren't all in the Painting & Sculpture department. Which paintings are housed in other departments and why? Should they be included in our dataset of paintings or not? We can take what we learned in the value counts and continue to filter the data to search for answers.

# %%
# Find the value counts for each department in the paintings data
df['Department'].value_counts()
# Out:
# Painting & Sculpture     2286
# Drawings & Prints          29
# Film                       27
# Fluxus Collection           5
# Media and Performance       3
# Name: Department, dtype: int64

# %%
# To find out more about why some paintings are housed in the Film department
# filter the paintings data by rows where the department is Film
# notice that these paintings are all by the same artist
df[df['Department']=='Film']
# Out:
#                                                   Title            Artist  \
# 1946                                A Thief in Paradise  Batiste Madalena
# 1947                                Beggar on Horseback  Batiste Madalena
# 1948                                         Classmates  Batiste Madalena
# 1949                                       The Freshman  Batiste Madalena
# 1950                                  The Haunted House  Batiste Madalena
# 1951                                    The Kid Brother  Batiste Madalena
# 1952                                The Loves of Carmen  Batiste Madalena
# 1953                                          The Noose  Batiste Madalena
# 1954                                So This Is Marriage  Batiste Madalena
# 1955                                        The Unknown  Batiste Madalena
# 1956                                            Variety  Batiste Madalena
# 1957                          Wanderer of the Wasteland  Batiste Madalena
# 1958                                            Variety  Batiste Madalena
# 1959                                  The Haunted House  Batiste Madalena
# 1960                            Clothes Make the Pirate  Batiste Madalena
# 1961  The Volga Boatman Martha Atwell: A Musical Sce...  Batiste Madalena
# 1962                    Fair and Muddy, Our Gang Comedy  Batiste Madalena
# 1963                               Sally of the Sawdust  Batiste Madalena
# 1964                                   Behind the Front  Batiste Madalena
# 1965                                        The Patriot  Batiste Madalena
# 1966                                        The Patriot  Batiste Madalena
# 1967                                   The Pony Express  Batiste Madalena
# 1968                               Sally of the Sawdust  Batiste Madalena
# 1971                                   The Pony Express  Batiste Madalena
# 1974                                Laugh, Clown, Laugh  Batiste Madalena
# 2090                                   Behind the Front  Batiste Madalena
# 2208                               The Road to Mandalay  Batiste Madalena
#
#       ConstituentID                   Date  \
# 1946        35204.0                   1925
# 1947        35204.0                   1925
# 1948        35204.0                   1924
# 1949        35204.0                   1925
# 1950        35204.0                   1928
# 1951        35204.0                   1927
# 1952        35204.0                c. 1927
# 1953        35204.0                c. 1928
# 1954        35204.0                   1925
# 1955        35204.0                   1927
# 1956        35204.0                   1926
# 1957        35204.0                   1924
# 1958        35204.0                   1926
# 1959        35204.0                   1928
# 1960        35204.0                   1926
# 1961        35204.0  1926 and c. 1924-1928
# 1962        35204.0                   1924
# 1963        35204.0                   1925
# 1964        35204.0                   1927
# 1965        35204.0                   1928
# 1966        35204.0                   1928
# 1967        35204.0                   1925
# 1968        35204.0                   1925
# 1971        35204.0                   1925
# 1974        35204.0                   1928
# 2090        35204.0                   1926
# 2208        35204.0                   1926
#
#                                                  Medium  \
# 1946                            Tempera on poster board
# 1947                            Tempera on poster board
# 1948                            Tempera on poster board
# 1949                  Tempera and paper on poster board
# 1950                            Tempera on poster board
# 1951                            Tempera on poster board
# 1952                            Tempera on poster board
# 1953                            Tempera on poster board
# 1954                            Tempera on poster board
# 1955                            Tempera on poster board
# 1956                            Tempera on poster board
# 1957                            Tempera on poster board
# 1958                            Tempera on poster board
# 1959                            Tempera on poster board
# 1960                            Tempera on poster board
# 1961  Tempera on poster board (The Volga Boatman) an...
# 1962                            Tempera on poster board
# 1963                            Tempera on poster board
# 1964                            Tempera on poster board
# 1965                            Tempera on poster board
# 1966                            Tempera on poster board
# 1967                            Tempera on poster board
# 1968                            Tempera on poster board
# 1971                            Tempera on poster board
# 1974                                Digital still image
# 2090                                   Gouache on paper
# 2208                                             Poster
#
#                                          Dimensions  \
# 1946        Overall: 44 x 23 3/4" (111.8 x 60.3 cm)
# 1947    Overall: 44 1/8 x 24 3/4" (112.1 x 62.9 cm)
# 1948        Overall: 44 x 24 3/4" (111.8 x 62.9 cm)
# 1949        Overall: 43 x 24 1/8" (109.2 x 61.3 cm)
# 1950    Overall: 43 3/4 x 24 3/4" (111.1 x 62.9 cm)
# 1951    Overall: 43 3/4 x 24 3/8" (111.1 x 61.9 cm)
# 1952              Overall: 43 x 24" (109.2 x 61 cm)
# 1953    Overall: 43 1/2 x 24 3/4" (110.5 x 62.9 cm)
# 1954    Overall: 43 1/8 x 24 1/4" (109.5 x 61.6 cm)
# 1955          Overall: 42 3/4 x 24" (108.6 x 61 cm)
# 1956        Overall: 43 x 24 1/8" (109.2 x 61.3 cm)
# 1957   Overall: 42 3/4 x 22 3/16" (108.6 x 56.4 cm)
# 1958    Overall: 41 1/2 x 23 1/4" (105.4 x 59.1 cm)
# 1959  Overall: 43 15/16 x 21 7/8" (111.6 x 55.6 cm)
# 1960   Overall: 43 1/2 x 24 9/16" (110.5 x 62.4 cm)
# 1961        Overall: 43 x 24 1/4" (109.2 x 61.6 cm)
# 1962                             42 9/16" x 23 7/8"
# 1963       Overall: 43 x 24 5/16" (109.2 x 61.8 cm)
# 1964                              41 3/4" x 21 1/2"
# 1965  Overall: 41 11/16 x 24 1/4" (105.9 x 61.6 cm)
# 1966  Overall: 41 11/16 x 24 1/4" (105.9 x 61.6 cm)
# 1967          Overall: 43 3/4 x 24" (111.1 x 61 cm)
# 1968            Overall: 44 1/2 x 26" (113 x 66 cm)
# 1971        Overall: 44 x 24 5/8" (111.8 x 62.5 cm)
# 1974                                            NaN
# 2090                       43 x 24" (109.2 x 61 cm)
# 2208                                            NaN
#
#                                 CreditLine AccessionNumber Classification  \
# 1946      Gift of Judith and Steven Katten      F2012.1307       Painting
# 1947  Courtesy of Judith and Steven Katten      F2012.1308       Painting
# 1948      Gift of Judith and Steven Katten      F2012.1309       Painting
# 1949  Courtesy of Judith and Steven Katten           F1922       Painting
# 1950  Courtesy of Judith and Steven Katten      TR14133.10       Painting
# 1951  Courtesy of Judith and Steven Katten      F2012.1310       Painting
# 1952  Courtesy of Judith and Steven Katten       TR14133.6       Painting
# 1953  Courtesy of Judith and Steven Katten           F1926       Painting
# 1954  Courtesy of Judith and Steven Katten       TR14133.7       Painting
# 1955  Courtesy of Judith and Steven Katten           F1929       Painting
# 1956  Courtesy of Judith and Steven Katten      TR14133.11       Painting
# 1957  Courtesy of Judith and Steven Katten       TR14133.8       Painting
# 1958  Courtesy of Judith and Steven Katten       TR14133.9       Painting
# 1959      Gift of Judith and Steven Katten           F1937       Painting
# 1960      Gift of Judith and Steven Katten           F1938       Painting
# 1961      Gift of Judith and Steven Katten           F1939       Painting
# 1962             Gift of the Katten Family           F1941       Painting
# 1963      Gift of Judith and Steven Katten           F1942       Painting
# 1964             Gift of the Katten Family           F1943       Painting
# 1965      Gift of Judith and Steven Katten           F1946       Painting
# 1966      Gift of Judith and Steven Katten           F1947       Painting
# 1967      Gift of Judith and Steven Katten           F1951       Painting
# 1968      Gift of Judith and Steven Katten           F1953       Painting
# 1971      Gift of Judith and Steven Katten           F1981       Painting
# 1974                                   NaN           F1986       Painting
# 2090             Gift of the Katten Family           F2497       Painting
# 2208       Purchase from the Katten Family       F2016.105       Painting
#
#      Department  ...            ArtistBio Nationality  Gender  BeginDate  \
# 1946       Film  ...  American, 1902–1988    American    male     1902.0
# 1947       Film  ...  American, 1902–1988    American    male     1902.0
# 1948       Film  ...  American, 1902–1988    American    male     1902.0
# 1949       Film  ...  American, 1902–1988    American    male     1902.0
# 1950       Film  ...  American, 1902–1988    American    male     1902.0
# 1951       Film  ...  American, 1902–1988    American    male     1902.0
# 1952       Film  ...  American, 1902–1988    American    male     1902.0
# 1953       Film  ...  American, 1902–1988    American    male     1902.0
# 1954       Film  ...  American, 1902–1988    American    male     1902.0
# 1955       Film  ...  American, 1902–1988    American    male     1902.0
# 1956       Film  ...  American, 1902–1988    American    male     1902.0
# 1957       Film  ...  American, 1902–1988    American    male     1902.0
# 1958       Film  ...  American, 1902–1988    American    male     1902.0
# 1959       Film  ...  American, 1902–1988    American    male     1902.0
# 1960       Film  ...  American, 1902–1988    American    male     1902.0
# 1961       Film  ...  American, 1902–1988    American    male     1902.0
# 1962       Film  ...  American, 1902–1988    American    male     1902.0
# 1963       Film  ...  American, 1902–1988    American    male     1902.0
# 1964       Film  ...  American, 1902–1988    American    male     1902.0
# 1965       Film  ...  American, 1902–1988    American    male     1902.0
# 1966       Film  ...  American, 1902–1988    American    male     1902.0
# 1967       Film  ...  American, 1902–1988    American    male     1902.0
# 1968       Film  ...  American, 1902–1988    American    male     1902.0
# 1971       Film  ...  American, 1902–1988    American    male     1902.0
# 1974       Film  ...  American, 1902–1988    American    male     1902.0
# 2090       Film  ...  American, 1902–1988    American    male     1902.0
# 2208       Film  ...  American, 1902–1988    American    male     1902.0
#
#       EndDate  Area (cm^2)    Aspect  OilPainting  YearCreated  AspectString
# 1946   1988.0  6741.948968  0.539773            N       1925.0      Portrait
# 1947   1988.0  7045.780221  0.560907            N       1925.0      Portrait
# 1948   1988.0  7025.820503  0.562500            N       1924.0      Portrait
# 1949   1988.0  6692.755321  0.561047            N       1925.0      Portrait
# 1950   1988.0  6985.901069  0.565714            N       1928.0      Portrait
# 1951   1988.0  6880.054083  0.557143            N       1927.0      Portrait
# 1952   1988.0  6658.077832  0.558140            N       1927.0      Portrait
# 1953   1988.0  6945.981634  0.568966            N       1928.0      Portrait
# 1954   1988.0  6746.989300  0.562319            N       1925.0      Portrait
# 1955   1988.0  6619.368077  0.561404            N       1927.0      Portrait
# 1956   1988.0  6692.755321  0.561047            N       1926.0      Portrait
# 1957   1988.0  6119.467884  0.519006            N       1924.0      Portrait
# 1958   1988.0  6225.012450  0.560241            N       1926.0      Portrait
# 1959   1988.0  6200.869257  0.497866            N       1928.0      Portrait
# 1960   1988.0  6893.360561  0.564655            N       1926.0      Portrait
# 1961   1988.0  6727.432810  0.563953            N       1926.0      Portrait
# 1962   1988.0  6556.011096  0.560940            N       1924.0      Portrait
# 1963   1988.0  6744.771554  0.565407            N       1925.0      Portrait
# 1964   1988.0  5791.140615  0.514970            N       1927.0      Portrait
# 1965   1988.0  6522.089657  0.581709            N       1928.0      Portrait
# 1966   1988.0  6522.089657  0.581709            N       1928.0      Portrait
# 1967   1988.0  6774.207097  0.548571            N       1925.0      Portrait
# 1968   1988.0  7464.531058  0.584270            N       1925.0      Portrait
# 1971   1988.0  6990.336561  0.559659            N       1925.0      Portrait
# 1974   1988.0          NaN       NaN            N       1928.0           NaN
# 2090   1988.0  6658.077832  0.558140            N       1926.0      Portrait
# 2208   1988.0          NaN       NaN            N       1926.0           NaN
#
# [27 rows x 31 columns]

# %% [markdown]
# #### Minimum, maximum, and average
#
# We can also calculate aggregates like the minimum, maximum, and mean of values in a DataFrame or Series. This is primarily useful for numeric values. For strings, aggregates are based on alphabetical order, with uppercase preceeding lowercase (for example, "B" would come before "a").
#
# Here are a few examples:
#
# - `mean()` to find the average of a range
# - `min()` to find the smallest value
# - `max()` to find the largest value
# - `sum()` to sum the values of a range

# %%
# Calculate the minimum values for each column with .min()

# %%
# Calculate the average height for all pieces of art in this collection with .mean()

# %%
# Calculate the minimum, maximum, and average diameter for art in this collection with .agg()

# %% [markdown]
# ### Group values using groupby
#
# We may be interested in seeing our data in groups. After the data has been grouped, we can do the same calculations on it as before (mean, min, max). In this example, we group the data based on the column `OilPainting` to see the average of each column based on whether or not it is an oil painting.
#
# We can do this by calling `groupby()` on our dataset and passing in the column we would like to group by. We will group our data by the column `OilPainting` and then use the `.mean()` method to find the average of every column based on those groups.

# %%
# Group the dataset by "OilPainting"


# This creates a groupby object that contains information about the groups

# %%
# Group the art based on the listed nationality of the artist


# We can also sort the grouped data by any column
# Find the mean, then sort by "Height (cm)"
# ascending=False puts the tallest groups at the top

# %% [markdown]
# You can also use `groupby()` to group data by multiple variables. We will create a hierarchical grouping of `OilPainting` and then `Gender` to see the counts of oil paintings by different genders. We can use `.mean()` to find the average for each of those subcategories, or we can use `.size()` to find counts of each category.

# %%
# Group the data by OilPainting and then Gender 
# find the counts of subcategories with .size()

# %% [markdown]
# ## Open work time
# You can use this time to ask questions, collaborate, or work on the following activities (on your own or in a group).
#
# All of the follow exercises will use a dataset about photos from the MoMA collection. All of the columns are the same as the examples above, but the contents of the rows will be different. You can run the first cell below to read in the dataset as a DataFrame.

# %%
photos_file_url = 'https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_photographs_final.csv'

photos = pd.read_csv(photos_file_url)

# Print out the first five columns of the dataset
photos.head()

# %% [markdown]
# ### Exercise 1: Find value counts
#
# 1a. How many different mediums were used  to create these photographs?
#
# 1b. What is the most common medium? Print out a list of how many of each of the mediums is listed with the most common at the top.

# %% [markdown]
# ### Exercise 2: Find the average, minimum and maximum
#
# Find the average, minimum, and maximum from the column 'Width (cm)'.

# %% [markdown]
# ### Exercise 3: Grouping Values
#
# Find the average year created for each department (Painting & Sculpture, Drawings & Prints, Film, Fluxus Collection, Media & Performance). Group the data using 'Department,' then show a table with the average 'YearCreated' for each department, sorted from oldest to newest.
#
# > Bonus discussion question: does showing the data this way tell the whole story? What other factors could affect the average year the art was created?

# %% [markdown]
# ### Exercise 4: Group values by two factors
#
# Find how many works of art each artist created using different mediums. Group by artist and medium to create a chart that shows how many works of art in the collection by each artist used each medium.

# %% [markdown]
# ## Further resources
#
# ### Filled version of this notebook
#
# [Python Open Labs Week 4 filled notebook](https://colab.research.google.com/github/ncsu-libraries-data-vis/python-open-labs/blob/main/Open_Lab_4_exploratory_analysis_with_pandas/filled_Open_Lab_4_exploratory_analysis_with_pandas.ipynb) - a version of this notebook with all code filled in for the guided activity and exercises.
# ### Learning resources
#
# - [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/index.html) - a free, online version of Jake VanderPlas' introduction to data science with Python, includes a chapter on data manipulation with pandas.
# - [Python Programming for Data Science](https://www.tomasbeuzen.com/python-programming-for-data-science/README.html) - a website providing a great overview of conducting data science with Python including pandas.
# - [Real Python](https://realpython.com/) contains a lot of different tutorials at different levels
# - [LinkedIn Learning](https://www.lynda.com/Python-training-tutorials/415-0.html) is free with NC State accounts and contains several video series for learning Python
# - [Dataquest](https://www.dataquest.io/) is a free then paid series of courses with an emphasis on data science
#
# ### Finding help with pandas
#
# The [Pandas website](https://pandas.pydata.org/) and [online documentation](http://pandas.pydata.org/pandas-docs/stable/) are useful resources, and of course the indispensible [Stack Overflow has a "pandas" tag](https://stackoverflow.com/questions/tagged/pandas).  There is also a (much younger, much smaller) [sister site dedicated to Data Science questions that has a "pandas" tag](https://datascience.stackexchange.com/questions/tagged/pandas) too.

# %% [markdown]
# ## Evaluation Survey
# Please, spend 1 minute answering these questions that help improve future workshops.
#
# https://go.ncsu.edu/dvs-eval

# %% [markdown]
# ## Credits
#
# This workshop was created by Claire Cahoon and Walt Gurley, adapted from previous workshop materials by Scott Bailey and Simon Wiles, of Stanford Libraries.
